# %% [markdown]
# # Testes com treinamento de IA

# %%
# !pip install -U scikit-learn
# !pip install -U pandas
# !pip install -U numpy
# !pip install -U matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import datetime

from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, classification_report

# %%
from helper_functions import prepare_data
from detect_and_plot_leiden import detect_and_plot

hu_data = prepare_data("HU")
hr_data = prepare_data("HR")
ro_data = prepare_data("RO")
partitions_hu = detect_and_plot(hu_data, resolution=1.0, plot=True, seed=1042, output_path='Communities/HU.png')
partitions_hr = detect_and_plot(hr_data, resolution=1.0, plot=True, seed=1042, output_path='Communities/HR.png')
partitions_ro = detect_and_plot(ro_data, resolution=1.0, plot=True, seed=1042, output_path='Communities/RO.png')
# Out:
# Grafo criado com 47538 nós e 222887 arestas
# Grafo criado com 54573 nós e 498202 arestas
# Grafo criado com 41773 nós e 125826 arestas
# Found 27 communities.
# Saved to: Communities/HU.png
# Found 25 communities.
# Saved to: Communities/HR.png
# Found 50 communities.
# Saved to: Communities/RO.png
